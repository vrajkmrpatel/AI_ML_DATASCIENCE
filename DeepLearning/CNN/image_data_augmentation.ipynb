# %% [markdown]
# <a href="https://colab.research.google.com/github/vrajkmrpatel/AI_ML_DATASCIENCE/blob/main/DeepLearning/CNN/image_data_augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
img = image.load_img('/content/18.jpg', target_size=(200,200))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
type(img)
# Out:
# PIL.Image.Image

# %%
datagen = ImageDataGenerator(
        rotation_range=40,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        width_shift_range=0.2,
        height_shift_range=0.2,
        fill_mode='reflect'
  )

# %%
img = image.img_to_array(img)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (200, 200, 3)

# %%
input_batch = img.reshape((1,200,200,3))

# %%
import os
import shutil

# Path to the directory to clear
directory_path = 'aug'

# Check if the directory exists and clear its contents
if os.path.exists(directory_path):
    for item in os.listdir(directory_path):
        item_path = os.path.join(directory_path, item)
        if os.path.isfile(item_path):
            os.remove(item_path)
        elif os.path.isdir(item_path):
            shutil.rmtree(item_path)
else:
    os.makedirs(directory_path) # Create the directory if it doesn't exist


i = 0

for output in datagen.flow(input_batch, batch_size=1, save_to_dir='aug'):
  i = i + 1
  if i == 10:
    break

# %%
# print all images from the aug directory
import os
aug_imgs = os.listdir('aug')
aug_imgs
# Out:
# ['_0_1125.png',
#  '_0_9701.png',
#  '_0_9504.png',
#  '_0_5425.png',
#  '_0_6615.png',
#  '_0_3733.png',
#  '_0_8830.png',
#  '_0_7055.png',
#  '_0_8691.png',
#  '_0_8340.png']

# %%
from IPython.display import Image, display

for img_name in aug_imgs:
  img_path = os.path.join('aug', img_name)
  print(f"Displaying: {img_name}")
  display(Image(filename=img_path))
# Out:
# Displaying: _0_1125.png
# Displaying: _0_9701.png
# Displaying: _0_9504.png
# Displaying: _0_5425.png
# Displaying: _0_6615.png
# Displaying: _0_3733.png
# Displaying: _0_8830.png
# Displaying: _0_7055.png
# Displaying: _0_8691.png
# Displaying: _0_8340.png
